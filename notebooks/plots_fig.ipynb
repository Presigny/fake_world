# %%
import sklearn.cluster as sk
import itertools
import sys
import matplotlib.pyplot as plt
#from kneed import KneeLocator
from sklearn.metrics import silhouette_score
from pathlib import Path
import geopandas as gpd
path = Path().cwd().parent / "src" #to add the src directory to the path regognized by Python
sys.path.append(str(path))
import methods_two_point_correlation as mtpc
import save_load_pickle as slp
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.optimize import curve_fit
from plot_func import plot4, plot5

from scipy.optimize import curve_fit
import numpy as np
import matplotlib.pyplot as plt

from measures import correlation_dimension_from_gdf

#To show plot in the notebook
# %matplotlib inline
#To show external zoomable plots
# %matplotlib qt


# %reload_ext autoreload
# %autoreload 2

data_dir = Path().cwd().parent/Path("data")

# %%
# Charger le shapefile (ou GeoJSON)
world = gpd.read_file(data_dir / "clean_transport_dataset/ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp")  # ou .geojson
world.plot()
# Sélectionner l'Allemagne
germany = world[world['NAME'] == 'Germany']
france = world[world['NAME'] == 'France']
switzerland = world[world['NAME'] == 'Switzerland']
# Sauvegarder en GeoJSON
germany.to_file(data_dir / "clean_transport_dataset"/ "Germany" / "germany_nat_earth.geojson", driver="GeoJSON")
france.to_file(data_dir / "clean_transport_dataset"/ "France" / "france_nat_earth.geojson", driver="GeoJSON")
switzerland.to_file(data_dir / "clean_transport_dataset"/ "Switzerland" / "switzerland_nat_earth.geojson", driver="GeoJSON")

# %% [markdown]
# # Determination of the power law exponents and the number of cluster

# %% [markdown]
# ## France Communes

# %%
name = "France"
data_type = "Commune"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_commune.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  34809
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:37<00:00, 15.76s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [02:38<00:00, 15.82s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:52<00:00, 12.89s/it]

# %%
name = "France"
data_type = "Commune"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_commune.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  34809
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:35<00:00, 15.57s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [02:33<00:00, 15.38s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:48<00:00, 12.70s/it]

# %%
name = "France"
data_type = "Commune"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_commune.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,1, "population_density") # Geopandas of the dataset

correlation_dimension_from_gdf(name, data_type, gdf_points, path_border_geojson)
# Out:
# Dataset: 34809 points
# Bootstrap: 10 échantillons de 10000 points...
# Bootstrap: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Dimension de corrélation D2 = 1.729 ± 0.003
# (array([ 11781.22919658,  13547.68698495,  15579.00449771,  17914.89435867,
#          20601.02363598,  23689.90664155,  27241.93159535,  31326.54122595,
#          36023.59038846,  41424.90724129,  47636.08850326,  54778.56388845,
#          62991.97007906,  72436.88064772,  83297.9452998 ,  95787.49980846,
#         110149.7172173 , 126665.38146745, 145657.37677422, 167497.0000718 ,
#         192611.21993525, 221491.02389322, 254701.01732267, 292890.46158582,
#         336805.96720694, 387306.09024277, 445378.11720829, 512157.36670616,
#         588949.38511027, 677255.47023278]),
#  array([0.00098898, 0.00129894, 0.00170409, 0.00223222, 0.00292252,
#         0.00382351, 0.00499876, 0.00652574, 0.00851041, 0.01108181,
#         0.01440833, 0.01870076, 0.0242146 , 0.03127883, 0.040289  ,
# ...

# %% [markdown]
# ## France Gares

# %%
name = "France"
data_type = "Gares"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_gares.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  3580
# step 1: 2pcf data
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# step 4: clustering
# 100%|██████████| 18/18 [00:04<00:00,  3.82it/s]

# %%
name = "France"
data_type = "Gares"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_gares.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  3580
# step 1: 2pcf data
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# step 4: clustering
# 100%|██████████| 18/18 [00:03<00:00,  4.81it/s]

# %%
name = "France"
data_type = "Gares"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_gares.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"


gdf_points = mtpc.load_df_to_gdf(path_points_csv,1, "population_density") # Geopandas of the dataset

correlation_dimension_from_gdf(name, data_type, gdf_points, path_border_geojson)
# Out:
# Dataset: 3580 points
# Dataset petit, calcul direct sur 3580 points...
# Dimension de corrélation D2 = 1.397 ± 0.017
# (array([  5543.18908984,   6546.5192811 ,   7731.45458386,   9130.86594809,
#          10783.57404259,  12735.42616802,  15040.56809371,  17762.94609988,
#          20978.08089304,  24775.16260425,  29259.5249869 ,  34555.56745012,
#          40810.20598709,  48196.9487294 ,  56920.7091863 ,  67223.49069155,
#          79391.09974835,  93761.07450553, 110732.0483064 , 130774.80806182,
#         154445.35421473, 182400.32458881, 215415.20998972, 254405.86687289,
#         300453.92385449, 354836.78686019, 419063.0752762 , 494914.47212643,
#         584495.1492296 , 690290.1384255 ]),
#  array([0.00100009, 0.0013385 , 0.00178649, 0.00237824, 0.00315481,
#         0.00416926, 0.00547873, 0.00714628, 0.0092754 , 0.0117974 ,
#         0.01485528, 0.01847899, 0.02272708, 0.02776547, 0.0339702 ,
#         0.0414936 , 0.05096692, 0.06315909, 0.07914557, 0.10024741,
# ...

# %% [markdown]
# ## France Routes

# %%
name = "France"
data_type = "Routes"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_routes.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  910160
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:35<00:00, 15.51s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [02:34<00:00, 15.40s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:53<00:00, 13.00s/it]

# %%
name = "France"
data_type = "Routes"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_routes.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  910160
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:34<00:00, 15.49s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [02:36<00:00, 15.60s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:57<00:00, 13.19s/it]

# %%
name = "France"
data_type = "Routes"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_routes.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"


gdf_points = mtpc.load_df_to_gdf(path_points_csv,1, "population_density") # Geopandas of the dataset

correlation_dimension_from_gdf(name, data_type, gdf_points, path_border_geojson)
# Out:
# Dataset: 910160 points
# Bootstrap: 10 échantillons de 10000 points...
# Bootstrap: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Dimension de corrélation D2 = 1.722 ± 0.003
# (array([ 11153.08872166,  12838.14001345,  14777.77529778,  17010.45809773,
#          19580.46315255,  22538.75439835,  25943.99559762,  29863.71365841,
#          34375.63771223,  39569.240505  ,  45547.51266726,  52429.0050478 ,
#          60350.17961097,  69468.11551651,  79963.62404427,  92044.83413362,
#         105951.31963999, 121958.85015295, 140384.85958617, 161594.74098282,
#         186009.09236424, 214112.05730913, 246460.92565937, 283697.18473712,
#         326559.24022213, 375897.05894781, 432689.02398688, 498061.3362679 ,
#         573310.34746212, 659928.26700836]),
#  array([0.00098877, 0.00127853, 0.00165431, 0.00214078, 0.00277157,
#         0.00358497, 0.00463884, 0.0060006 , 0.00776404, 0.01003385,
#         0.01295433, 0.01671212, 0.02154605, 0.02776368, 0.03571647,
# ...

# %% [markdown]
# ## France High-Voltage grid

# %%
name = "France"
data_type = "Postes RTE"
path_points_csv = data_dir / "clean_transport_dataset" /name / "postes-electriques-rte.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  4973
# step 1: 2pcf data
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# step 4: clustering
# 100%|██████████| 18/18 [00:05<00:00,  3.34it/s]

# %%
name = "France"
data_type = "Postes RTE"
path_points_csv = data_dir / "clean_transport_dataset" /name / "postes-electriques-rte.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  4973
# step 1: 2pcf data
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# step 4: clustering
# 100%|██████████| 18/18 [00:05<00:00,  3.30it/s]

# %%
name = "France"
data_type = "Postes RTE"
path_points_csv = data_dir / "clean_transport_dataset" /name / "postes-electriques-rte.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"


gdf_points = mtpc.load_df_to_gdf(path_points_csv,1, "population_density") # Geopandas of the dataset

correlation_dimension_from_gdf(name, data_type, gdf_points, path_border_geojson)
# Out:
# Calcul de la dimension de corrélation sur 4973 points...
# Calcul C(r): 100%|██████████| 30/30 [00:00<00:00, 103.95it/s]
# Dimension de corrélation D2 = 1.524 ± 0.009
# (array([  6707.69706756,   7865.6491796 ,   9223.49897339,  10815.75485629,
#          12682.8824342 ,  14872.33290482,  17439.74898287,  20450.37900456,
#          23980.7351494 ,  28120.53792145,  32974.99630704,  38667.48155695,
#          45342.66254454,  53170.18238179,  62348.969731  ,  73112.29437967,
#          85733.69556099, 100533.93368254, 117889.14213427, 138240.38634597,
#         162104.87302824, 190089.09446863, 222904.24193239, 261384.27988383,
#         306507.14036708, 359419.57618017, 421466.30446136, 494224.18134307,
#         579542.27618835, 679588.86385695]),
#  array([0.00100001, 0.00123911, 0.00153856, 0.00192124, 0.00239726,
#         0.00300877, 0.00378609, 0.00482816, 0.0061298 , 0.00774965,
#         0.00978591, 0.01246069, 0.01589145, 0.02020436, 0.02598667,
# ...

# %% [markdown]
# ## France Low-Voltage grid

# %%
name = "France"
data_type = "Postes ENEDIS"
path_points_csv = data_dir / "clean_transport_dataset" /name / "postes-electriques-enedis.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  921054
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:34<00:00, 15.48s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [02:36<00:00, 15.61s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:55<00:00, 13.09s/it]

# %%
name = "France"
data_type = "Postes ENEDIS"
path_points_csv = data_dir / "clean_transport_dataset" /name / "postes-electriques-enedis.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  921054
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:34<00:00, 15.47s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [02:35<00:00, 15.59s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:58<00:00, 13.24s/it]

# %%
name = "France"
data_type = "Postes ENEDIS"
path_points_csv = data_dir / "clean_transport_dataset" /name / "postes-electriques-enedis.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,1, "population_density") # Geopandas of the dataset

correlation_dimension_from_gdf(name, data_type, gdf_points, path_border_geojson)
# Out:
# Dataset: 921054 points
# Bootstrap: 10 échantillons de 10000 points...
# Bootstrap: 100%|██████████| 10/10 [00:13<00:00,  1.38s/it]
# Dimension de corrélation D2 = 1.617 ± 0.008
# (array([  8572.1376431 ,   9959.12241578,  11570.52341223,  13442.65151525,
#          15617.6927631 ,  18144.65895853,  21080.49208774,  24491.34743601,
#          28454.08431335,  33057.99798181,  38406.83181121,  44621.11500481,
#          51840.87857231,  60228.81075158,  69973.92298222,  81295.80903926,
#          94449.59330102, 109731.67965423, 127486.43058063, 148113.92692978,
#         172078.9832349 , 199921.62172025, 232269.24101879, 269850.75380659,
#         313513.0119278 , 364239.88912956, 423174.45141213, 491644.71457508,
#         571193.56937312, 663613.54860734]),
#  array([0.00100338, 0.00128076, 0.00162858, 0.00206783, 0.00262098,
#         0.00332139, 0.00421332, 0.00534018, 0.00677039, 0.00857811,
#         0.01087668, 0.013838  , 0.01766188, 0.02262639, 0.02912661,
# ...

# %% [markdown]
# ## Suisse stops

# %%
name = "Switzerland"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "swiss_stops.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "switzerland_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  93955
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:58<00:00, 17.88s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [03:03<00:00, 18.35s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:50<00:00, 12.83s/it]

# %%
name = "Switzerland"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "swiss_stops.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "switzerland_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  93955
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:57<00:00, 17.71s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [02:59<00:00, 18.00s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:49<00:00, 12.76s/it]

# %%
name = "Switzerland"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "swiss_stops.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "switzerland_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,1, "population_density") # Geopandas of the dataset

correlation_dimension_from_gdf(name, data_type, gdf_points, path_border_geojson)
# Out:
# Dataset: 93955 points
# Bootstrap: 10 échantillons de 10000 points...
# Bootstrap: 100%|██████████| 10/10 [00:11<00:00,  1.19s/it]
# Dimension de corrélation D2 = 1.431 ± 0.005
# (array([  1530.46166152,   1811.26632058,   2143.59220264,   2536.89227199,
#           3002.35389538,   3553.21706508,   4205.15100868,   4976.69989813,
#           5889.81033616,   6970.4556244 ,   8249.37457044,   9762.94584892,
#          11554.22278807,  13674.15801563,  16183.0527995 ,  19152.27230898,
#          22666.2755873 ,  26825.01797756,  31746.79433879,  37571.60392707,
#          44465.13265524,  52623.46600602,  62278.66665681,  73705.37547083,
#          87228.62361894, 103233.07804688, 122173.98327398, 144590.11076133,
#         171119.08419234, 202515.5165913 ]),
#  array([0.00100371, 0.00127703, 0.00163273, 0.00208822, 0.00267729,
#         0.00343609, 0.00440143, 0.00563032, 0.0071678 , 0.00907495,
#         0.01143879, 0.01432277, 0.01793384, 0.02252294, 0.02848525,
# ...

# %% [markdown]
# ## Allemagne stops

# %%
name = "Germany"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "localtransitgermany.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "germany_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  664438
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:35<00:00, 15.54s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [02:38<00:00, 15.86s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:55<00:00, 13.10s/it]

# %%
name = "Germany"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "localtransitgermany.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "germany_nat_earth.geojson"

plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")
# Out:
# number of data points :  664438
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:38<00:00, 15.89s/it]
# 2pcf done
# step 2: plot points
# step 3: 2pcf random
# Bootstrap computation: 100%|██████████| 10/10 [02:39<00:00, 15.94s/it]
# step 4: clustering
# 100%|██████████| 18/18 [03:55<00:00, 13.07s/it]

# %%
name = "Germany"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "localtransitgermany.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "germany_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,1, "population_density") # Geopandas of the dataset

correlation_dimension_from_gdf(name, data_type, gdf_points, path_border_geojson)
# Out:
# Dataset: 664438 points
# Bootstrap: 10 échantillons de 10000 points...
# Bootstrap: 100%|██████████| 10/10 [00:13<00:00,  1.38s/it]
# Dimension de corrélation D2 = 1.661 ± 0.004
# (array([  7610.21335518,   8806.39927399,  10190.60367343,  11792.37960919,
#          13645.9253351 ,  15790.81444308,  18272.84076767,  21144.99609404,
#          24468.60154377,  28314.61679374,  32765.15508017,  37915.23633351,
#          43874.81587401,  50771.13198097,  58751.42245682,  67986.06818523,
#          78672.23079891,  91038.06212199, 105347.57525957, 121906.28133319,
#         141067.71220762, 163240.96847069, 188899.45381711, 218590.9823171 ,
#         252949.47436226, 292708.49099953, 338716.89561416, 391956.97734195,
#         453565.42314925, 524857.58633933]),
#  array([0.00097693, 0.00125503, 0.00161557, 0.00208336, 0.00269221,
#         0.00347953, 0.00449543, 0.00580687, 0.00750046, 0.00970626,
#         0.01256118, 0.01624345, 0.02095207, 0.02702041, 0.0348241 ,
# ...

# %% [markdown]
# # Weight analysis

# %%
threshold = 1 # minimal number of inhabitants for the city to be considered
N_run = 5 # number of random catalog generated for computing the 2PCF
size = 7000 #number of points each random catalog has
k =  3  #number of time the 2PCF computing process is repeated to estimate variance
rmax = 1.6e5 #maximal distance between two points considered, if None, taken the max from data
scale = "log" #scale at which to bin the data, recommended "log"
nbins = 20 # number of bins to consider in the computation of 2PCF (betweem rmin and rmax)
bootstrap_size = 10_000
bootstrap_N_real = 10

parameters = {"threshold":threshold,"N_run":N_run,"size":size,"k":k,"rmax":rmax,"scale":scale,"nbins":nbins,"bootstrap_size":bootstrap_size,"bootstrap_N_real":bootstrap_N_real }

Nr_prime = size
N_sample = 2000

def plot_metadata(name, data_type, path_points_csv, path_border_geojson, Nsampl = N_sample,param = parameters, log_ax= False):
    def power_law(r, A, gamma):
        return A * r**(-gamma)

    gdf_points = mtpc.load_df_to_gdf(path_points_csv,threshold,  "population_density")

    if len(gdf_points) < 6*Nsampl:
        raise ValueError("Not enough point to split into 6 groups of size " + str(Nsampl))

    r, xi6, labels, l_av_bin_metadata = mtpc.compute_two_point_correlation_density_groups(
        gdf_points,
        path_border_geojson,
        name,
        param,
        Nr_prime,
        False,
        rmax,
        Nsampl
    )

    colors = ["blue", "blue", "blue", "orange", "orange", "orange"]
    linestyles = ["-", "--", ":", ":", "--", "-"]
        
    plt.figure(figsize=(10,6))

    for i in range(6):

        r_i = r
        xi_i = xi6[i][:-1]

        mask = (xi_i > 0) & (r_i > 0)
        r_fit = r_i[mask]
        xi_fit = xi_i[mask]

        # --- FIT LOG-LOG ---
        log_r = np.log(r_fit)
        log_xi = np.log(xi_fit)

        # régression linéaire : log(xi) = a + b log(r)
        b, a = np.polyfit(log_r, log_xi, 1)
        gamma = -b              # parce que b = -gamma
        A = np.exp(a)

        gamma_str = f"{gamma:.2f}"

        # --- PLOT ---
        plt.plot(
            r_i, 
            xi_i, 
            color=colors[i],
            linestyle=linestyles[i],
            label=f"{labels[i]} γ = {gamma_str}, pop_dens = {l_av_bin_metadata[i]:.2f}"
        )

    plt.xlabel("r")
    plt.ylabel("ξ(r)")
    plt.legend(
        loc='upper center',         # placer la légende au centre horizontalement
        bbox_to_anchor=(0.5, -0.15), # 0.5 = centre horizontal, -0.15 = en dessous du graphe
        ncol=2                      # nombre de colonnes dans la légende
    )
    plt.grid(True)
    if log_ax == True:
        plt.semilogy()
    plt.show()

# %%
name = "France"
data_type = "Commune"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_commune.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,threshold,  "population_density")

plot_metadata(name, data_type, path_points_csv, path_border_geojson)
# Out:
# 100%|██████████| 6/6 [01:10<00:00, 11.83s/it]

# %%
name = "France"
data_type = "Gares"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_gares.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,threshold,  "population_density")

plot_metadata(name, data_type, path_points_csv, path_border_geojson, Nsampl = 500)
# Out:
# 100%|██████████| 6/6 [01:00<00:00, 10.17s/it]

# %%
name = "France"
data_type = "Routes"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_routes.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,threshold,  "population_density")

plot_metadata(name, data_type, path_points_csv, path_border_geojson, log_ax= True)
# Out:
# 100%|██████████| 6/6 [00:57<00:00,  9.62s/it]

# %%
name = "France"
data_type = "Postes RTE"
path_points_csv = data_dir / "clean_transport_dataset" /name / "postes-electriques-rte.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,threshold,  "population_density")

plot_metadata(name, data_type, path_points_csv, path_border_geojson, Nsampl = 500, log_ax= True)
# Out:
# 100%|██████████| 6/6 [00:59<00:00,  9.96s/it]

# %%
name = "France"
data_type = "Postes ENEDIS"
path_points_csv = data_dir / "clean_transport_dataset" /name / "postes-electriques-enedis.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,threshold,  "population_density")

plot_metadata(name, data_type, path_points_csv, path_border_geojson, Nsampl = 10000,log_ax= True)
# Out:
# 100%|██████████| 6/6 [01:53<00:00, 18.84s/it]

# %%
name = "Switzerland"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "swiss_stops.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "switzerland_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,threshold,  "population_density")

plot_metadata(name, data_type, path_points_csv, path_border_geojson, log_ax= True)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]/home/ee272361/Nextcloud2/Emery_Shared/Programmes/FakeWorld/fake_world/src/methods_two_point_correlation.py:306: RuntimeWarning: divide by zero encountered in divide
#   return (Nr*(Nr_prime-1)*DD)/(Nd*(Nd-1)*RR)-(((Nr_prime-1)*DR)/(Nd*RR))+1
# /home/ee272361/Nextcloud2/Emery_Shared/Programmes/FakeWorld/fake_world/src/methods_two_point_correlation.py:306: RuntimeWarning: invalid value encountered in divide
#   return (Nr*(Nr_prime-1)*DD)/(Nd*(Nd-1)*RR)-(((Nr_prime-1)*DR)/(Nd*RR))+1
# 100%|██████████| 6/6 [00:37<00:00,  6.23s/it]

# %%
name = "Germany"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "localtransitgermany.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "germany_nat_earth.geojson"

gdf_points = mtpc.load_df_to_gdf(path_points_csv,threshold,  "population_density")

plot_metadata(name, data_type, path_points_csv, path_border_geojson,Nsampl = 10000,log_ax= True)
# Out:
#  17%|█▋        | 1/6 [00:15<01:16, 15.31s/it]/home/ee272361/Nextcloud2/Emery_Shared/Programmes/FakeWorld/fake_world/src/methods_two_point_correlation.py:306: RuntimeWarning: divide by zero encountered in divide
#   return (Nr*(Nr_prime-1)*DD)/(Nd*(Nd-1)*RR)-(((Nr_prime-1)*DR)/(Nd*RR))+1
# /home/ee272361/Nextcloud2/Emery_Shared/Programmes/FakeWorld/fake_world/src/methods_two_point_correlation.py:306: RuntimeWarning: invalid value encountered in subtract
#   return (Nr*(Nr_prime-1)*DD)/(Nd*(Nd-1)*RR)-(((Nr_prime-1)*DR)/(Nd*RR))+1
# 100%|██████████| 6/6 [01:26<00:00, 14.48s/it]

# %% [markdown]
# # Attention ! Probleme avec la fonction SP

# %%
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import Polygon
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def soneira_peebles_model_gdf_all(lamb, eta, L, R, erase_nodes=False):
    position = [(0, 0)]
    all_positions = []
    all_ages = []
    rng = np.random.default_rng()
    
    # Génération des positions
    for i in range(L):
        l_pos = []
        l_age = []
        for x, y in position:
            l_random = (R / (lamb ** i)) * rng.random((eta, 2))
            for x_rand, y_rand in l_random:
                new_point = (x_rand - x, y_rand - y)
                l_pos.append(new_point)
                l_age.append(i)  # âge = étape i
        position = l_pos
        all_positions += l_pos
        all_ages += l_age
    
    # Conversion en array
    position_array = np.array(all_positions)
    
    # Matrice de distance
    distance_matrix = cdist(position_array, position_array)
    
    # GeoDataFrame des points
    points = [Point(x, y) for x, y in position_array]
    gdf_points = gpd.GeoDataFrame({
        "age": all_ages,
        "geometry": points
    })
    
    # GeoDataFrame des cercles
    circles = [Point(x, y).buffer(R / (lamb ** age)) for (x, y), age in zip(all_positions, all_ages)]
    gdf_circles = gpd.GeoDataFrame({
        "age": all_ages,
        "geometry": circles
    })
    
    return gdf_points, gdf_circles, distance_matrix


# ========================
# Exemple d'utilisation
# ========================
lamb, eta, L, R = 2, 2, 4, 1
gdf_points, gdf_circles, dist_matrix = soneira_peebles_model_gdf_all(lamb, eta, L, R)

# Affichage
fig, ax = plt.subplots(figsize=(8,8))

# Normalisation pour la colorbar
ages = gdf_points["age"]
norm = plt.Normalize(vmin=ages.min(), vmax=ages.max())
cmap = cm.viridis

# Afficher les cercles
gdf_circles.plot(ax=ax, facecolor='none', edgecolor=cmap(norm(gdf_circles["age"])), linewidth=0.8)

# Afficher les points
sc = ax.scatter(
    [p.x for p in gdf_points.geometry],
    [p.y for p in gdf_points.geometry],
    c=gdf_points["age"],
    cmap=cmap,
    alpha=0.7
)

# Colorbar
plt.colorbar(sc, label="Âge du nœud")
ax.set_aspect('equal')
plt.show()

# %%
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def soneira_peebles_model_gdf_circle(lamb, eta, L, R, erase_nodes=False):
    rng = np.random.default_rng()
    position = [(0, 0)]  # point initial
    all_positions = []
    all_ages = []

    for i in range(L):
        new_positions = []
        new_ages = []
        for cx, cy in position:
            for _ in range(eta):
                # Génération uniforme dans un cercle
                theta = 2 * np.pi * rng.random()
                radius = (R / (lamb ** i)) * np.sqrt(rng.random())
                x_new = cx + radius * np.cos(theta)
                y_new = cy + radius * np.sin(theta)
                new_positions.append((x_new, y_new))
                new_ages.append(i)
        position = new_positions  # nouvelle génération
        all_positions += new_positions
        all_ages += new_ages

    # Effacement aléatoire optionnel
    if isinstance(erase_nodes, int) and erase_nodes > 0:
        temp_positions = list(all_positions)
        temp_ages = list(all_ages)
        while erase_nodes != 0 and len(temp_positions) > 0:
            index = rng.choice(range(len(temp_positions)))
            temp_positions.pop(index)
            temp_ages.pop(index)
            erase_nodes -= 1
        all_positions = temp_positions
        all_ages = temp_ages

    # Conversion en array pour calcul distance
    position_array = np.array(all_positions)
    distance_matrix = cdist(position_array, position_array)

    # GeoDataFrame des points
    gdf_points = gpd.GeoDataFrame({
        "age": all_ages,
        "geometry": [Point(x, y) for x, y in position_array]
    })

    # GeoDataFrame des cercles
    gdf_circles = gpd.GeoDataFrame({
        "age": all_ages,
        "geometry": [Point(x, y).buffer(R / (lamb ** age)) for (x, y), age in zip(all_positions, all_ages)]
    })

    return gdf_points, gdf_circles, distance_matrix


# =======================
# Exemple d'utilisation
# =======================
lamb, eta, L, R = 2, 2, 4, 1
gdf_points, gdf_circles, dist_matrix = soneira_peebles_model_gdf_circle(lamb, eta, L, R)

# Visualisation
fig, ax = plt.subplots(figsize=(8, 8))

ages = gdf_points["age"]
norm = plt.Normalize(vmin=ages.min(), vmax=ages.max())
cmap = cm.viridis

# Cercles
gdf_circles.plot(ax=ax, facecolor='none', edgecolor=cmap(norm(gdf_circles["age"])), linewidth=0.8)

# Points
sc = ax.scatter(
    [p.x for p in gdf_points.geometry],
    [p.y for p in gdf_points.geometry],
    c=gdf_points["age"],
    cmap=cmap,
    alpha=0.7
)

plt.colorbar(sc, label="Âge du nœud")
ax.set_aspect('equal')
plt.show()

# %% [markdown]
# Les fonction SP model renvoie la position finale mais stocke quand meme des valeurs intermediaire demander a Charley pq

# %% [markdown]
# # Test these measure with SP model  (with age)

# %% [markdown]
# Adapter la fonction SP model with border pour ajouter l'age
# Tester un sp model border age pour retrouver les 2pcf ci dessus
# Avec l'hypotese que l'age c'est l'inverse de la population density, est-ce qu'on peut dire quelque chose sur les ponderation de 2pcf comme ci dessus

# %%
threshold = 1 # minimal number of inhabitants for the city to be considered
N_run = 5 # number of random catalog generated for computing the 2PCF
size = 7000 #number of points each random catalog has
k =  3  #number of time the 2PCF computing process is repeated to estimate variance
rmax = 1.6e5 #maximal distance between two points considered, if None, taken the max from data
scale = "log" #scale at which to bin the data, recommended "log"
nbins = 20 # number of bins to consider in the computation of 2PCF (betweem rmin and rmax)
bootstrap_size = 10_000
bootstrap_N_real = 10

parameters = {"threshold":threshold,"N_run":N_run,"size":size,"k":k,"rmax":rmax,"scale":scale,"nbins":nbins,"bootstrap_size":bootstrap_size,"bootstrap_N_real":bootstrap_N_real }

Nr_prime = size
N_sample = 1000

def plot_metadata(name, data_type, gdf_points, path_border_geojson, Nsampl = N_sample,param = parameters, log_ax= False):
    def power_law(r, A, gamma):
        return A * r**(-gamma)

    # gdf_points = mtpc.load_df_to_gdf(path_points_csv,threshold,  "population_density")

    if len(gdf_points) < 6*Nsampl:
        raise ValueError("Not enough point to split into 6 groups of size " + str(Nsampl))

    r, xi6, labels, l_av_bin_metadata = mtpc.compute_two_point_correlation_density_groups2(
        gdf_points,
        path_border_geojson,
        name,
        param,
        Nr_prime,
        False,
        rmax,
        Nsampl
    )

    colors = ["blue", "blue", "blue", "orange", "orange", "orange"]
    linestyles = ["-", "--", ":", ":", "--", "-"]
        
    plt.figure(figsize=(10,6))

    for i in range(6):

        r_i = r
        xi_i = xi6[i][:-1]

        mask = (xi_i > 0) & (r_i > 0)
        r_fit = r_i[mask]
        xi_fit = xi_i[mask]

        # --- FIT LOG-LOG ---
        log_r = np.log(r_fit)
        log_xi = np.log(xi_fit)

        # régression linéaire : log(xi) = a + b log(r)
        b, a = np.polyfit(log_r, log_xi, 1)
        gamma = -b              # parce que b = -gamma
        A = np.exp(a)

        gamma_str = f"{gamma:.2f}"

        # --- PLOT ---
        plt.plot(
            r_i, 
            xi_i, 
            color=colors[i],
            linestyle=linestyles[i],
            label=f"{labels[i]} γ = {gamma_str}, age = {l_av_bin_metadata[i]:.2f}"
        )

    plt.xlabel("r")
    plt.ylabel("ξ(r)")
    plt.legend(
        loc='upper center',         # placer la légende au centre horizontalement
        bbox_to_anchor=(0.5, -0.15), # 0.5 = centre horizontal, -0.15 = en dessous du graphe
        ncol=2                      # nombre de colonnes dans la légende
    )
    plt.grid(True)
    if log_ax == True:
        plt.semilogy()
    plt.show()

# %%
import numpy as np
import geopandas as gpd
from shapely.geometry import Point, MultiPolygon
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def get_largest_polygon(gdf):
    """Retourne le plus grand polygone d'un GeoDataFrame."""
    geom = gdf.geometry.iloc[0]
    if isinstance(geom, MultiPolygon):
        return max(geom.geoms, key=lambda p: p.area)
    return geom

def soneira_peebles_model_in_shape(lamb, eta, L, R, gdf_edge, erase_nodes=False, max_retry=1000):
    rng = np.random.default_rng()

    # extraire le polygone dans lequel les points doivent rester
    target_poly = get_largest_polygon(gdf_edge)

    # Vérifier si point initial est à l'intérieur, sinon le replacer aléatoirement
    cx0, cy0 = target_poly.representative_point().coords[0]
    position = [(cx0, cy0)]  # point initial garanti à l'intérieur

    all_positions = []
    all_ages = []

    for i in range(L):
        new_positions = []
        new_ages = []

        for cx, cy in position:
            for _ in range(eta):

                # On essaie jusqu'à ce que le point tombe dans le polygone
                for _ in range(max_retry):
                    theta = 2 * np.pi * rng.random()
                    radius = (R / (lamb ** i)) * np.sqrt(rng.random())
                    x_new = cx + radius * np.cos(theta)
                    y_new = cy + radius * np.sin(theta)
                    pt = Point(x_new, y_new)

                    if target_poly.contains(pt):
                        new_positions.append((x_new, y_new))
                        new_ages.append(i)
                        break
                else:
                    print(f"⚠️ Warning: max_retry reached at level {i}, skipping a point")

        position = new_positions
        all_positions = new_positions#+
        all_ages = new_ages#+

    # Effacement aléatoire optionnel
    if isinstance(erase_nodes, int) and erase_nodes > 0:
        idx = rng.choice(len(all_positions), size=erase_nodes, replace=False)
        mask = np.ones(len(all_positions), dtype=bool)
        mask[idx] = False
        all_positions = [all_positions[i] for i in range(len(all_positions)) if mask[i]]
        all_ages = [all_ages[i] for i in range(len(all_ages)) if mask[i]]

    # Conversion array + distance matrix
    pos_array = np.array(all_positions)
    # distance_matrix = cdist(pos_array, pos_array)

    # Points
    gdf_points = gpd.GeoDataFrame({
        "age": all_ages,
        "geometry": [Point(x, y) for x, y in pos_array]
    }, crs=gdf_edge.crs)

    # Cercles
    gdf_circles = gpd.GeoDataFrame({
        "age": all_ages,
        "geometry": [Point(x, y).buffer(R / (lamb ** age)) for (x, y), age in zip(all_positions, all_ages)]
    }, crs=gdf_edge.crs)

    return gdf_points, gdf_circles#, distance_matrix

# %%
name = "France"
data_type = "Commune"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_commune.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

# plot4(name, data_type, path_points_csv, path_border_geojson, "population_density")

# %%
gdf_edge = gpd.read_file(path_border_geojson)

def lambda_from_fit(gamma,eta):
    return eta * np.exp(gamma-2)

gdf_points, gdf_circles = soneira_peebles_model_in_shape(
    lamb=lambda_from_fit(0.4,6),
    eta=6,
    L= int(round(np.log(34809) / np.log(6))),
    R=10*np.sqrt(500_000/np.pi)/1000,
    gdf_edge=gdf_edge
)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

# bordure
# gdf_edge.plot(ax=ax, facecolor="none", edgecolor="black")

# Color map
ages = gdf_points["age"]
norm = plt.Normalize(vmin=ages.min(), vmax=ages.max())
cmap = cm.viridis

# cercles
gdf_circles.plot(
    ax=ax,
    facecolor="none",
    alpha = 1/(gdf_points.age+1)**2,
    edgecolor=[cmap(norm(a)) for a in gdf_circles.age],
    linewidth=0.5
)

# points
sc = ax.scatter(
    gdf_points.geometry.x,
    gdf_points.geometry.y,
    c=gdf_points.age,
    cmap=cmap,
    alpha = 1/(gdf_points.age+1)**2,
    s=8
)

plt.colorbar(sc, label="Âge")
ax.set_aspect("equal")
plt.show()

# %%
len(gdf_points)
# Out:
# 55986

# %%
name = "France"
data_type = "Commune"
path_points_csv = data_dir / "clean_transport_dataset" /name / "noeuds_route500_commune.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

plot_metadata(name, data_type, gdf_points, path_border_geojson)
# Out:
# 100%|██████████| 6/6 [01:03<00:00, 10.53s/it]

# %%
plot5(name, data_type, gdf_points, path_border_geojson, "population_density")
# Out:
# number of data points :  46656
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:03<00:00, 12.34s/it]
# 2pcf done
# /home/ee272361/Nextcloud2/Emery_Shared/Programmes/FakeWorld/fake_world/src/plot_func.py:68: RuntimeWarning: invalid value encountered in power
#   model = (r/r0)**(-gamma)

# %%
name = "France"
data_type = "Gares"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_edge = gpd.read_file(path_border_geojson)

nb_cluster = 6
nb_nodes = 3580
gamma_exp = 1.033

gdf_points, gdf_circles, dist_matrix = soneira_peebles_model_in_shape(
    lamb=lambda_from_fit(gamma_exp,nb_cluster),
    eta=nb_cluster,
    L= int(round(np.log(nb_nodes) / np.log(nb_cluster))),
    R=10*np.sqrt(500_000/np.pi)/1000,
    gdf_edge=gdf_edge
)

plot_metadata(name, data_type, gdf_points, path_border_geojson)
plot5(name, data_type, gdf_points, path_border_geojson, "population_density")
# Out:
# 100%|██████████| 6/6 [01:12<00:00, 12.03s/it]
# number of data points :  9330
# step 1: 2pcf data
# 2pcf done
# Fit failed!
# /home/ee272361/Nextcloud2/Emery_Shared/Programmes/FakeWorld/fake_world/src/plot_func.py:68: RuntimeWarning: invalid value encountered in power
#   model = (r/r0)**(-gamma)

# %%
name = "France"
data_type = "Routes"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_edge = gpd.read_file(path_border_geojson)

nb_cluster = 7
nb_nodes = 910160
gamma_exp = 0.715

gdf_points, gdf_circles = soneira_peebles_model_in_shape(
    lamb=lambda_from_fit(gamma_exp,nb_cluster),
    eta=nb_cluster,
    L= int(round(np.log(nb_nodes) / np.log(nb_cluster))),
    R=10*np.sqrt(500_000/np.pi)/1000,
    gdf_edge=gdf_edge
)
print("plots")
plot_metadata(name, data_type, gdf_points, path_border_geojson, Nsampl=3000)
plot5(name, data_type, gdf_points, path_border_geojson, "population_density")
# Out:
# plots
# 100%|██████████| 6/6 [00:56<00:00,  9.46s/it]
# number of data points :  823543
# step 1: 2pcf data
# Bootstrap computation: 100%|██████████| 10/10 [02:17<00:00, 13.76s/it]
# 2pcf done

# %%
name = "France"
data_type = "Postes RTE"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_edge = gpd.read_file(path_border_geojson)

nb_cluster = 6
nb_nodes = 4973
gamma_exp = 0.981

gdf_points, gdf_circles = soneira_peebles_model_in_shape(
    lamb=lambda_from_fit(gamma_exp,nb_cluster),
    eta=nb_cluster,
    L= int(round(np.log(nb_nodes) / np.log(nb_cluster))),
    R=10*np.sqrt(500_000/np.pi)/1000,
    gdf_edge=gdf_edge
)

plot_metadata(name, data_type, gdf_points, path_border_geojson)
plot5(name, data_type, gdf_points, path_border_geojson, "population_density")
# Out:
# 100%|██████████| 6/6 [00:54<00:00,  9.07s/it]
# number of data points :  9330
# step 1: 2pcf data
# 2pcf done

# %%
name = "France"
data_type = "Postes ENEDIS"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "france_nat_earth.geojson"

gdf_edge = gpd.read_file(path_border_geojson)

nb_cluster = 6
nb_nodes = 921054
gamma_exp = 0.981

gdf_points, gdf_circles = soneira_peebles_model_in_shape(
    lamb=lambda_from_fit(gamma_exp,nb_cluster),
    eta=nb_cluster,
    L= int(round(np.log(nb_nodes) / np.log(nb_cluster))),
    R=10*np.sqrt(500_000/np.pi)/1000,
    gdf_edge=gdf_edge
)

plot_metadata(name, data_type, gdf_points, path_border_geojson,Nsampl=20_000)
plot5(name, data_type, gdf_points, path_border_geojson, "population_density")
# Out:
# 100%|██████████| 6/6 [01:45<00:00, 17.61s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 19
#       9 gamma_exp = 0.981
#      11 gdf_points, gdf_circles = soneira_peebles_model_in_shape(
#      12     lamb=lambda_from_fit(gamma_exp,nb_cluster),
#      13     eta=nb_cluster,
#    (...)     16     gdf_edge=gdf_edge
#      17 )
# ---> 19 plot_metadata(name, data_type, gdf_points, path_border_geojson,Nsampl=10_000)
#      20 plot5(name, data_type, gdf_points, path_border_geojson, "population_density")
#
# Cell In[2], line 25, in plot_metadata(name, data_type, gdf_points, path_border_geojson, Nsampl, param, log_ax)
#      22 if len(gdf_points) < 6*Nsampl:
#      23     raise ValueError("Not enough point to split into 6 groups of size " + str(Nsampl))
# ---> 25 r, xi6, labels, l_av_bin_metadata = mtpc.compute_two_point_correlation_density_groups2(
# ...

# %%
name = "Switzerland"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "swiss_stops.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "switzerland_nat_earth.geojson"

gdf_edge = gpd.read_file(path_border_geojson)

nb_cluster = 12
nb_nodes = 93955
gamma_exp = 0.987

gdf_points, gdf_circles = soneira_peebles_model_in_shape(
    lamb=lambda_from_fit(gamma_exp,nb_cluster),
    eta=nb_cluster,
    L= int(round(np.log(nb_nodes) / np.log(nb_cluster))),
    R=10*np.sqrt(41285/np.pi)/1000,
    gdf_edge=gdf_edge
)

plot_metadata(name, data_type, gdf_points, path_border_geojson,Nsampl=15500)
plot5(name, data_type, gdf_points, path_border_geojson, "population_density")
# Out:
#   0%|          | 0/6 [00:23<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 20
#      10 gamma_exp = 0.987
#      12 gdf_points, gdf_circles = soneira_peebles_model_in_shape(
#      13     lamb=lambda_from_fit(gamma_exp,nb_cluster),
#      14     eta=nb_cluster,
#    (...)     17     gdf_edge=gdf_edge
#      18 )
# ---> 20 plot_metadata(name, data_type, gdf_points, path_border_geojson,Nsampl=15500)
#      21 plot5(name, data_type, gdf_points, path_border_geojson, "population_density")
#
# Cell In[2], line 25, in plot_metadata(name, data_type, gdf_points, path_border_geojson, Nsampl, param, log_ax)
#      22 if len(gdf_points) < 6*Nsampl:
#      23     raise ValueError("Not enough point to split into 6 groups of size " + str(Nsampl))
# ---> 25 r, xi6, labels, l_av_bin_metadata = mtpc.compute_two_point_correlation_density_groups2(
# ...

# %%
name = "Germany"
data_type = "Stops"
path_points_csv = data_dir / "clean_transport_dataset" /name / "localtransitgermany.csv"
path_border_geojson = data_dir / "clean_transport_dataset"/ name / "germany_nat_earth.geojson"

gdf_edge = gpd.read_file(path_border_geojson)

nb_cluster = 4
nb_nodes = 664438
gamma_exp = 0.728

gdf_points, gdf_circles = soneira_peebles_model_in_shape(
    lamb=lambda_from_fit(gamma_exp,nb_cluster),
    eta=nb_cluster,
    L= int(round(np.log(nb_nodes) / np.log(nb_cluster))),
    R=10*np.sqrt(357588/np.pi)/1000,
    gdf_edge=gdf_edge
)

plot_metadata(name, data_type, gdf_points, path_border_geojson,Nsampl=2500)
plot5(name, data_type, gdf_points, path_border_geojson, "population_density")
